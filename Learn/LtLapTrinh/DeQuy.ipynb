# %%
from math import * 
def A():
    print('A')
def B():
    A()
    print('B')
def C():
    B()
    print('C')
if __name__ == '__main__':
    C()

# %% [markdown]
# ## Ham de quy

# %%
def A():
    print('A')
    A() # De quy

if __name__ == '__main__':
    A()

# %%
from math import * 
def S(n):
    if n == 0 : 
        return 0
    else :
        return n + S(n-1) # de quy
if __name__ == '__main__':
    n = 4
    print(S(n))
# Out:
# 10
