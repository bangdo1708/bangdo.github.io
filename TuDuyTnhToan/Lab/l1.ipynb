# %% [markdown]
# W2A1

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# W2A2

# %%
name = input('nhap ten cua ban ')
print(f'Hello {name}')
# Out:
# Hello bang

# %% [markdown]
# W2A3

# %%
a = int(input())
b = int(input())
print(f'tong cua a va b la {a+b}')
print(f'hieu cua a va b la {a-b}')
print(f'tich cua a va b la {a*b}')
print(f'phan nguyen cua a va b la {a//b}')
print(f'phan du cua a va b la {a%b}')
print(f'chia thuc cua a va b la {f'{a/b:.2f}'}')
# Out:
# tong cua a va b la 9
# hieu cua a va b la 1
# tich cua a va b la 20
# phan nguyen cua a va b la 1
# phan du cua a va b la 1
# chia thuc cua a va b la 1.25

# %% [markdown]
# W2A6

# %%
chu = str(input())
print(ord(chu) , chr(ord(chu)-32))
# Out:
# 97 A

# %% [markdown]
# W2A5

# %%
a, b = map(int, input().split())
print(a**b)
# Out:
# 16

# %% [markdown]
# W2A9

# %%
p = float(input())
x = p * 1.4 + 10
print(f'{x:.2f}')
# Out:
# 32932845.60

# %% [markdown]
# W2A13

# %%
a, b = map(int, input().split())
print((a*b)%10)
# Out:
# 5
